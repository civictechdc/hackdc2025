# %%
import json
import os
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## Identify document types

# %%
search_root = Path.cwd() / 'specific'
docket_ids = os.listdir(search_root)

# %%
for docket in docket_ids:
    document_dir = search_root / docket / 'raw-data' / 'documents'
    json_docs = [doc.replace("_content.htm", ".json") for doc in os.listdir(document_dir) if doc.endswith('.htm')]
    for json_path in json_docs:
        with open(document_dir / json_path, 'r') as file:
            data = json.load(file)
            attributes = data['data']['attributes']
            print(f"{json_path}: {attributes['documentType']}")
    print()
# Out:
# CMS-2019-0039-0001.json: Proposed Rule
# CMS-2019-0039-1625.json: Rule
# CMS-2019-0039-1626.json: Rule
# CMS-2019-0039-0397.json: Proposed Rule
#
# DEA-2016-0015-0003.json: Proposed Rule
# DEA-2016-0015-0006.json: Proposed Rule
#
# DEA-2024-0059-0001.json: Proposed Rule
# DEA-2024-0059-42928.json: Proposed Rule
#
# HHS-ONC-2019-0002-0257.json: Proposed Rule
# HHS-ONC-2019-0002-0001.json: Proposed Rule
#
#
# CMS-2022-0163-0001.json: Notice

# %% [markdown]
# ## Create document dataframe
# - document name
# - docket id
# - document type
# - posted date

# %%
doc_df = {'document_id': [], 'docket_id': [], 'document_type': [], 'posted_date': [], 'file_url': []}

for docket in docket_ids:
    document_dir = search_root / docket / 'raw-data' / 'documents'
    json_docs = [doc.replace("_content.htm", ".json") for doc in os.listdir(document_dir) if doc.endswith('.htm')]
    for json_path in json_docs:
        with open(document_dir / json_path, 'r') as file:
            data = json.load(file)
            attributes = data['data']['attributes']
            doc_df['document_id'].append(data['data']['id'])
            doc_df['docket_id'].append(attributes['docketId'])
            doc_df['document_type'].append(attributes['documentType'])
            doc_df['posted_date'].append(attributes['postedDate'])
            doc_df['file_url'].append(attributes['fileFormats'])

# %%
doc_df = pd.DataFrame(doc_df)
doc_df.to_csv("documents.csv")

# %% [markdown]
# ## Read in comments data and duplicate dataframes for processing

# %%
docs_df = doc_df.copy()
comments = pd.read_csv("CMS-2019-0039-Comments.csv",sep = "|")

# %%
cmts_df = comments[comments['docketId']=="CMS-2019-0039"].copy()

# %%
cmts_df = cmts_df.rename(columns={"postedDate":"posted_date"})

# %%
docs_df = doc_df[doc_df.docket_id == "CMS-2019-0039"].copy()
docs_df
# Out:
#           document_id      docket_id  document_type           posted_date  \
# 0  CMS-2019-0039-0001  CMS-2019-0039  Proposed Rule  2019-05-03T04:00:00Z
# 1  CMS-2019-0039-1625  CMS-2019-0039           Rule  2020-05-01T04:00:00Z
# 2  CMS-2019-0039-1626  CMS-2019-0039           Rule  2021-12-10T05:00:00Z
# 3  CMS-2019-0039-0397  CMS-2019-0039  Proposed Rule  2019-04-23T04:00:00Z
#
#                                             file_url
# 0  [{'fileUrl': 'https://downloads.regulations.go...
# 1  [{'fileUrl': 'https://downloads.regulations.go...
# 2  [{'fileUrl': 'https://downloads.regulations.go...
# 3  [{'fileUrl': 'https://downloads.regulations.go...

# %% [markdown]
# ## Create "windows" to match comments to specific documents

# %%
import pandas as pd
import numpy as np

# 1)  Make sure both frames are UTC datetimes
docs_df['posted_date'] = pd.to_datetime(docs_df['posted_date'],  utc=True)
cmts_df['posted_date'] = pd.to_datetime(cmts_df['posted_date'], utc=True)

# sort by postedDate (ascending) and assign incremental order starting at 1
docs_df = docs_df.sort_values("posted_date", ascending=True).reset_index(drop=True)
docs_df["doc_order"] = docs_df.index + 1      # 1, 2, 3, …

# 2)  Sort docs in the order you want the windows to appear
docs_df = docs_df.sort_values('doc_order')

# 3)  Build the window edges ------------------------------------------
#     left edges = each doc's own postedDate
#     right edge = next doc's postedDate, or "forever" for the last one
bins   = docs_df['posted_date'].tolist() + [pd.Timestamp.max.tz_localize('UTC')]
labels = docs_df['doc_order'].tolist()                 # what we'll assign

# 4)  Slot every comment timestamp into those windows ------------------
cmts_df['cmt_doc_order'] = pd.cut(
    cmts_df['posted_date'],
    bins=bins,
    labels=labels,
    right=False           # makes the interval [left, right)
).astype('Int64')         # optional: convert to nullable integer

# %%
cmts_df
# Out:
#       Unnamed: 0       docketId commentOnDocumentId          comment_id  \
# 0              0  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-0002
# 1              1  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-0003
# 2              2  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-0004
# 3              3  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-0005
# 4              4  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-0006
# ...          ...            ...                 ...                 ...
# 1616        1616  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-1619
# 1617        1617  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-1620
# 1618        1618  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-1621
# 1619        1619  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-1622
# 1620        1620  CMS-2019-0039  CMS-2019-0039-0001  CMS-2019-0039-1623
#
#                 modifyDate               posted_date           receiveDate  \
# 0     2019-03-06T16:15:36Z 2019-03-06 05:00:00+00:00  2019-03-06T05:00:00Z
# 1     2019-03-06T16:15:38Z 2019-03-06 05:00:00+00:00  2019-03-05T05:00:00Z
# 2     2019-03-06T16:15:39Z 2019-03-06 05:00:00+00:00  2019-03-05T05:00:00Z
# 3     2019-03-06T16:15:40Z 2019-03-06 05:00:00+00:00  2019-03-05T05:00:00Z
# 4     2019-03-06T16:15:41Z 2019-03-06 05:00:00+00:00  2019-03-05T05:00:00Z
# ...                    ...                       ...                   ...
# 1616  2019-06-11T13:00:15Z 2019-06-11 04:00:00+00:00  2019-05-29T04:00:00Z
# 1617  2019-06-11T13:00:17Z 2019-06-11 04:00:00+00:00  2019-05-28T04:00:00Z
# 1618  2019-06-11T13:00:19Z 2019-06-11 04:00:00+00:00  2019-05-28T04:00:00Z
# 1619  2019-06-11T13:00:20Z 2019-06-11 04:00:00+00:00  2019-05-27T04:00:00Z
# 1620  2019-06-11T13:00:21Z 2019-06-11 04:00:00+00:00  2019-05-24T04:00:00Z
#
#                                                 comment  \
# 0     In order to promote the secure, electronic exc...
# 1     file code CMS-9115-P<br/><br/>Please assist th...
# 2     The efficiency and accuracy of patient health ...
# 3     2015 CEHRT call for requirements and standards...
# 4     I am submitting a comment that calls for inclu...
# ...                                                 ...
# 1616  Thank you for the opportunity to comment, plea...
# 1617  There are those concerned about liabilities wi...
# 1618                               See attached file(s)
# 1619  Honorable Seema Verma<br/>Administrator<br/>Ce...
# 1620                               See attached file(s)
#
#                                            comment_text  cmt_doc_order
# 0                                                   NaN           <NA>
# 1                                                   NaN           <NA>
# 2                                                   NaN           <NA>
# 3                                                   NaN           <NA>
# 4     QUA INC \n\nPeg Graham, MBA, MPH \nFounder \nT...           <NA>
# ...                                                 ...            ...
# 1616  May 29, 2019 \n\nSeema Verma \nAdministrator, ...              2
# 1617                                                NaN              2
# 1618  Via Electronic Submission \n\nApril 11, 2019 \...              2
# 1619                                                NaN              2
# 1620  The Commonwealth of Massachusetts \nExecutive ...              2
#
# [1621 rows x 10 columns]

# %% [markdown]
# ## Pull document text from file url

# %%
docs_df['downloadUrl'] = docs_df.file_url[1][0]['fileUrl']

# %%
# Minimal: add doc_text to existing df using its downloadUrl column
import requests, tempfile, os
from pathlib import Path
from bs4 import BeautifulSoup
from pdfminer.high_level import extract_text
from tqdm.notebook import tqdm

# ---------- tiny helpers ----------
def _html_to_text(content: bytes) -> str:
    return BeautifulSoup(content, "html.parser").get_text("\n")

def _pdf_to_text(content: bytes) -> str:
    with tempfile.NamedTemporaryFile(suffix=".pdf", delete=False) as tmp:
        tmp.write(content); tmp.flush()
        text = extract_text(tmp.name)
    os.unlink(tmp.name)
    return text

def fetch_and_extract(url: str | None) -> str:
    if not url or pd.isna(url):
        return ""
    try:
        r = requests.get(url, timeout=30); r.raise_for_status()
        ext = Path(url).suffix.lower()
        if ext in (".htm", ".html"):
            return _html_to_text(r.content)
        if ext == ".txt":
            return r.content.decode("utf‑8", "replace")
        if ext == ".pdf":
            return _pdf_to_text(r.content)
    except Exception as e:
        print(" !", url, e)
    return ""

# ---------- pull the files ----------
docs_df["doc_text"] = [
    fetch_and_extract(u) for u in tqdm(docs_df["downloadUrl"], desc="Downloading", unit="file")
]

docs_df[["downloadUrl", "doc_text"]].head()
# Out:
# Downloading:   0%|          | 0/4 [00:00<?, ?file/s]
#                                          downloadUrl  \
# 0  https://downloads.regulations.gov/CMS-2019-003...
# 1  https://downloads.regulations.gov/CMS-2019-003...
# 2  https://downloads.regulations.gov/CMS-2019-003...
# 3  https://downloads.regulations.gov/CMS-2019-003...
#
#                                             doc_text
# 0  7610 \n\nFederal  Register / Vol.  84,  No.  4...
# 1  7610 \n\nFederal  Register / Vol.  84,  No.  4...
# 2  7610 \n\nFederal  Register / Vol.  84,  No.  4...
# 3  7610 \n\nFederal  Register / Vol.  84,  No.  4...

# %% [markdown]
# ## Match comments to document windows

# %%
# docs_df
import re

import pandas as pd
import numpy as np

def add_comm_ref(df: pd.DataFrame, text_col: str = "text") -> pd.DataFrame:
    """
    Pull the slice between the first and last occurrence of the word
    'commenter' (case‑insensitive) in each cell of *text_col* and store it
    in a new column called 'comm_ref'.

    Parameters
    ----------
    df : pd.DataFrame
        The dataframe you want to enrich.
    text_col : str, default 'text'
        Column that contains the raw text.

    Returns
    -------
    pd.DataFrame
        Same dataframe with an extra 'comm_ref' column.
    """
    word = "commenter"
    wlen = len(word)

    def _extract(txt: str):
        if not isinstance(txt, str):
            return np.nan                     # non‑string cells
        lower = txt.lower()
        first = lower.find(word)
        last  = lower.rfind(word)
        if first == -1 or last == -1 or last <= first:
            return np.nan                     # < 2 occurrences
        return txt[first:last + wlen]         # inclusive slice

    df = df.copy()
    df["comm_ref"] = df[text_col].apply(_extract)
    return df
docs_df = add_comm_ref(docs_df, "doc_text")

# %%
docs_df
# Out:
#           document_id      docket_id  document_type               posted_date  \
# 0  CMS-2019-0039-0397  CMS-2019-0039  Proposed Rule 2019-04-23 04:00:00+00:00
# 1  CMS-2019-0039-0001  CMS-2019-0039  Proposed Rule 2019-05-03 04:00:00+00:00
# 2  CMS-2019-0039-1625  CMS-2019-0039           Rule 2020-05-01 04:00:00+00:00
# 3  CMS-2019-0039-1626  CMS-2019-0039           Rule 2021-12-10 05:00:00+00:00
#
#                                             file_url  doc_order  \
# 0  [{'fileUrl': 'https://downloads.regulations.go...          1
# 1  [{'fileUrl': 'https://downloads.regulations.go...          2
# 2  [{'fileUrl': 'https://downloads.regulations.go...          3
# 3  [{'fileUrl': 'https://downloads.regulations.go...          4
#
#                                          downloadUrl  \
# 0  https://downloads.regulations.gov/CMS-2019-003...
# 1  https://downloads.regulations.gov/CMS-2019-003...
# 2  https://downloads.regulations.gov/CMS-2019-003...
# 3  https://downloads.regulations.gov/CMS-2019-003...
#
#                                             doc_text  \
# 0  7610 \n\nFederal  Register / Vol.  84,  No.  4...
# 1  7610 \n\nFederal  Register / Vol.  84,  No.  4...
# 2  7610 \n\nFederal  Register / Vol.  84,  No.  4...
# 3  7610 \n\nFederal  Register / Vol.  84,  No.  4...
#
#                                             comm_ref
# 0  commenters recommended aligning \nexisting sta...
# 1  commenters recommended aligning \nexisting sta...
# 2  commenters recommended aligning \nexisting sta...
# 3  commenters recommended aligning \nexisting sta...

# %%
merged = pd.merge(left = docs_df, right = cmts_df, left_on = "doc_order", right_on = "cmt_doc_order", how = "inner")

# %%
docs_df.to_csv("docs_df.csv")
cmts_df.to_csv("cmts_df.csv")

# %%
# merged.to_csv("merged.csv", index = False)
